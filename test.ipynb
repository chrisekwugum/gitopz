# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisekwugum/gitopz/blob/testing/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %%
# crearte a new function
def greet(name):
  print(f"hello, {name} good morning!")

# %%
greet("Chris")
# Out:
# hello, Chris good morning!
